# %%
import json

with open('authors.tang.json', 'rt', encoding='utf-8') as fp:
    data = fp.read()
authors = json.loads(data)
names = [author['name'] for author in authors]
print(names)
# Out:
# ['太宗皇帝', '高宗皇帝', '中宗皇帝', '睿宗皇帝', '明皇帝', '肅宗皇帝', '德宗皇帝', '文宗皇帝', '宣宗皇帝', '昭宗皇帝', '文德皇后', '則天皇后', '徐賢妃', '上官昭容', '楊貴妃', '江妃', '章懷太子', '韓王元嘉', '越王貞', '信安王禕', '宜芬公主', '女學士宋氏若華', '尚宮宋氏若昭', '尚宮宋氏若憲', '鮑氏君徽', '蕭妃', '南唐先主李昪', '嗣主璟', '後主煜', '韓王從善', '吉王從謙', '蜀高祖王建', '後主衍', '吳越王錢鏐', '後王錢俶', '後蜀嗣主孟昶', '閩王王繼鵬', '蜀太后徐氏', '蜀太妃徐氏', '褚亮', '不詳', '張說', '武則天', '魏徵', '包佶', '林鍾宮', '盧從愿', '劉晃', '韓休', '王晙', '崔玄童', '賈曾', '蘇頲', '何鸞', '蔣挺', '源光裕', '賀知章、源乾曜', '于邵', '姚崇', '蔡孚', '沈佺期', '盧懷慎', '姜皎', '崔日用', '李乂', '裴璀', '魏徵、褚亮', '郭子儀', '劉晏', '鄭餘慶', '鄭絪', '段文昌', '牛僧孺', '李回', '夏侯孜', '蕭倣', '李舒', '徐彥伯', '丘說', '張齊賢', '鄭善玉', '薛稷', '徐堅', '胡雄', '劉子玄', '員半千', '祝欽明', '許孟容', '陳京', '馮伉', '崔邠', '張薦', '歸登', '杜羔', '李逢吉', '孟簡', '裴度', '王涯', '趙光逢、張衮', '崔居儉、盧文紀', '張昭', '張籍', '李賀', '盧照鄰', '李白', '劉駕', '僧貫休', '鄭世翼', '張循之', '劉方平', '皇甫冉', '李端', '于濆', '孟郊', '僧齊己', '韋應物', '元稹', '羅隱', '盧仝', '劉氏雲', '王勃', '莊南傑', '岑參', '柳宗元', '王維', '翁綬', '楊師道', '王建', '僧皎然', '鮑溶', '賈馳', '張祜', '竇威', '陳子昂', '張易之', '王昌齡', '馬戴', '杜甫', '王之渙', '耿[湋]', '劉濟', '于鵠', '劉希夷'
# ...

# %%
authors = json.loads(data)
print(type(authors))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-694e0e4221e4> in <module>()
# ----> 1 authors = json.loads(data)
#       2 print(type(authors))
#
# d:\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# d:\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# d:\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
# ...
